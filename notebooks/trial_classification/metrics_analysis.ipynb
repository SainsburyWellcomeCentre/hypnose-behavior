# %%
# %load_ext autoreload
# %autoreload 2
import sys
from hypnose_behavior.metric_analysis.run import batch_run_all_metrics_with_merge, run_all_metrics 
from hypnose_behavior.io.load_results import load_session_results
from ipywidgets import widgets
from IPython.display import display

# %matplotlib widget

# %%
# Run all behavioral metrics. Can be run on one or multiple subjects and dates ([...] for multiple subject, or None for all subjects). Specify protocol to filter sessions (None for all protocols).
# Date selection either as list of dates [YYYYMMDD] or as range(start_date, end_date) for a date range (inclusive)
all_metrics = batch_run_all_metrics_with_merge(subjids=[45, 46, 50, 51], dates=(20260130, 20260219), protocol=None)

# %%
results = load_session_results(40, 20251116)

# %%
metrics = run_all_metrics(results)
