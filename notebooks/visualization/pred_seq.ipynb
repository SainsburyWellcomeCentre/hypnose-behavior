# %% [markdown]
# # Predicted Sequence Analysis
#
# Starter notebook for predicted-sequence visualizations.

# %%
from hypnose_behavior.visualization.pred_seq_utils import (
    cummulative_poke_time,
    fa_analysis,
    first_odor_poke_duration,
    last_odor_poke_time,
    performance,
    poke_time_all_pos,
    response_time,
    trial_poke_duration,
    valve_to_reward,
)
from hypnose_behavior.io.save import use_style
use_style("presentation")

# %%
# Example: last-odor poke time boxplots
last_odor_poke_time(subjids=[58], dates=(20260511, 20260612), save=True, moving_avg=False, window_size=10, step_size=1)

# %%
# Example: trial poke duration boxplots
trial_poke_duration(subjids=[59], dates=(20260512, 20260520), save=True, moving_avg=True, window_size=10, step_size=1)

# %%
# Example: first-odor poke duration
first_odor_poke_duration(subjids=[59], dates=[20260513])

# %%
# Example: poke duration pooled across positions
poke_time_all_pos(subjids=[59], dates=(20260512, 20260520), save=True, moving_avg=False, window_size=10, step_size=1)

# %%
cummulative_poke_time(subjids=[59], dates=(20260512, 20260520), save=True, moving_avg=False, window_size=10, step_size=1)

# %%
# Example: response time by odor sequence
response_time(subjids=[59], dates=(20260512, 20260520), save=True, moving_avg=False, window_size=10, step_size=1)

# %%
valve_to_reward(subjids=[59], dates=(20260512, 20260520), save=True, moving_avg=False, window_size=10, step_size=1)

# %%
performance(subjids=[59], dates=(20260512, 20260521), save=True, moving_avg=False, window_size=10, step_size=3)

# %%
# Example: FA analysis (aborted trials)
fa_analysis(subjids=[59], dates=(20260512, 20260521), fa_types=["FA_time_in"], save=True, moving_avg=False, window_size=10, step_size=1)
